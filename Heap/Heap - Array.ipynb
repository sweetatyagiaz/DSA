# %% [markdown]
# ### **Build Heap from Array**
#
# Complexity: O(n)

# %%
def build_max_heap(arr):
    for idx in range((len(arr) // 2) - 1, -1, -1):
        print('idx: ', idx)

def heapify(arr, )

# %%
arr = [4, 10, 3, 5, 1]
print(build_max_heap(arr))
# Out:
# idx:  1
# idx:  0
# None
